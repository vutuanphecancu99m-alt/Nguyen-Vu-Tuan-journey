# %%
print( "bắt đầu hành trình AI engineer 26/4/2026")
# Out:
# bắt đầu hành trình AI engineer 26/4/2026

# %%
print("hello")
# Out:
# hello

# %%
print("hello, tôi tên là tuấn ")
# Out:
# hello, tôi tên là tuấn

# %%
# hello

# %%
print("hello#")
# Out:
# hello#

# %%
#date
doanh_thu=1500
chi_phi=500
loi_nhuan=doanh_thu-chi_phi
print(loi_nhuan)
# Out:
# 1000

# %%
# tểt
ten_cuahang = "hà nội"
doanh_thu= 10000000
chi_phi=50000
chiet_khau = 5/100
loi_nhuan=doanh_thu-chi_phi
hoa_hong=loi_nhuan*chiet_khau
# Thêm :, để phân cách hàng nghìn
print(f"cửa hàng {ten_cuahang} đạt lợi nhuận: {loi_nhuan:,} VND, chiết khấu cho nhân viên {hoa_hong:,} VND")
# Out:
# cửa hàng hà nội đạt lợi nhuận: 9,950,000 VND, chiết khấu cho nhân viên 497,500.0 VND
